# %% [markdown]
# ## Extracting and Loading X-Ray Data

# %%
from tqdm.autonotebook import tqdm
from vincent_util import (
    load_nih_dataset,
    print_dataset_info,
    show_sample_images,
    )

imgpath = "/Users/yeochanyoun/Desktop/uchic/courses/Winter2025/Bayesian/final_proj/images-224"

# Load dataset
dataset, dataloader = load_nih_dataset(
    imgpath=imgpath,
    extract_dir="./data/NIH/extracted",
    views=['PA'],
    unique_patients=True
)


# Print dataset information
print_dataset_info(dataset)

# Show sample images
show_sample_images(dataset)
# Out:
# /var/folders/h1/y8sqv_qx1458y77vrdqj6sfh0000gn/T/ipykernel_32951/1779531855.py:1: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# Loading dataset from /Users/yeochanyoun/Desktop/uchic/courses/Winter2025/Bayesian/final_proj/images-224
# Dataset size: 28868
#
# Available pathologies:
# 1. Atelectasis
# 2. Cardiomegaly
# 3. Consolidation
# 4. Edema
# 5. Effusion
# 6. Emphysema
# 7. Fibrosis
# 8. Hernia
# 9. Infiltration
# 10. Mass
# 11. Nodule
# 12. Pleural_Thickening
# 13. Pneumonia
# 14. Pneumothorax
#
# Pathology counts:
# Atelectasis:
#   Present: 1557
#   Absent: 27311
#   Percentage: 5.39%
#
# Cardiomegaly:
#   Present: 729
#   Absent: 28139
#   Percentage: 2.53%
#
# Consolidation:
#   Present: 384
#   Absent: 28484
#   Percentage: 1.33%
#
# Edema:
#   Present: 39
#   Absent: 28829
#   Percentage: 0.14%
#
# Effusion:
#   Present: 1269
#   Absent: 27599
#   Percentage: 4.40%
#
# Emphysema:
#   Present: 264
#   Absent: 28604
#   Percentage: 0.91%
#
# Fibrosis:
#   Present: 556
#   Absent: 28312
#   Percentage: 1.93%
#
# Hernia:
#   Present: 81
#   Absent: 28787
#   Percentage: 0.28%
#
# Infiltration:
#   Present: 3273
#   Absent: 25595
#   Percentage: 11.34%
#
# Mass:
#   Present: 1213
#   Absent: 27655
#   Percentage: 4.20%
#
# Nodule:
#   Present: 1609
#   Absent: 27259
#   Percentage: 5.57%
#
# Pleural_Thickening:
#   Present: 745
#   Absent: 28123
#   Percentage: 2.58%
#
# Pneumonia:
#   Present: 175
#   Absent: 28693
#   Percentage: 0.61%
#
# Pneumothorax:
#   Present: 243
#   Absent: 28625
#   Percentage: 0.84%
#
# Sample 0 structure: dict_keys(['idx', 'lab', 'img'])
# Sample 1 structure: dict_keys(['idx', 'lab', 'img'])
# Sample 2 structure: dict_keys(['idx', 'lab', 'img'])
# Sample 3 structure: dict_keys(['idx', 'lab', 'img'])

# %% [markdown]
# ## Loading Pre-trained Dense Net Model

# %%
import torchxrayvision as xrv

model = xrv.models.DenseNet(weights="densenet121-res224-nih")

# %% [markdown]
# ## Running Base Inference Pipeline with Model

# %%
import torch
from torch.utils.data import DataLoader
from vincent_util import run_inference

# Create a small subset for testing
small_subset = torch.utils.data.Subset(dataset, indices=range(4))
test_loader = DataLoader(small_subset, batch_size=4)

# Run inference
preds = run_inference(model, test_loader, num_samples=4)
# Out:
# Dataset structure:
# Using subset dataset
# Original dataset type: <class 'torchxrayvision.datasets.NIH_Dataset'>
#
# Number of pathologies: 14
# Pathologies: ['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema', 'Effusion', 'Emphysema', 'Fibrosis', 'Hernia', 'Infiltration', 'Mass', 'Nodule', 'Pleural_Thickening', 'Pneumonia', 'Pneumothorax']
#
# Batch information:
# Batch type: <class 'dict'>
# Batch keys: dict_keys(['idx', 'lab', 'img'])
# Images shape: torch.Size([4, 1, 224, 224])
# Labels shape: torch.Size([4, 14])
#
# Predictions shape: torch.Size([4, 18])
#
# Debug - Prediction vector length: 18
# Debug - Number of pathologies: 14
# Debug - Model pathologies: ['Atelectasis', 'Consolidation', 'Infiltration', 'Pneumothorax', 'Edema', 'Emphysema', 'Fibrosis', 'Effusion', 'Pneumonia', 'Pleural_Thickening', 'Cardiomegaly', 'Nodule', 'Mass', 'Hernia', '', '', '', '']
#
# Debug - Prediction vector length: 18
# Debug - Number of pathologies: 14
# Debug - Model pathologies: ['Atelectasis', 'Consolidation', 'Infiltration', 'Pneumothorax', 'Edema', 'Emphysema', 'Fibrosis', 'Effusion', 'Pneumonia', 'Pleural_Thickening', 'Cardiomegaly', 'Nodule', 'Mass', 'Hernia', '', '', '', '']
#
# Debug - Prediction vector length: 18
# Debug - Number of pathologies: 14
# Debug - Model pathologies: ['Atelectasis', 'Consolidation', 'Infiltration', 'Pneumothorax', 'Edema', 'Emphysema', 'Fibrosis', 'Effusion', 'Pneumonia', 'Pleural_Thickening', 'Cardiomegaly', 'Nodule', 'Mass', 'Hernia', '', '', '', '']
#
# Debug - Prediction vector length: 18
# Debug - Number of pathologies: 14
# Debug - Model pathologies: ['Atelectasis', 'Consolidation', 'Infiltration', 'Pneumothorax', 'Edema', 'Emphysema', 'Fibrosis', 'Effusion', 'Pneumonia', 'Pleural_Thickening', 'Cardiomegaly', 'Nodule', 'Mass', 'Hernia', '', '', '', '']

# %% [markdown]
# ## Taking subset and splitting into train and test

# %%
train_dataset = torch.utils.data.Subset(dataset, indices=range(10000))
train_loader = DataLoader(train_dataset, batch_size=4)

test_dataset = torch.utils.data.Subset(dataset, indices=range(1000, 1500))
test_loader = DataLoader(test_dataset, batch_size=4)

# %%
small_dataset = torch.utils.data.Subset(dataset, indices=range(1000))
small_loader = DataLoader(test_dataset, batch_size=4)

# %% [markdown]
# ## Bayesian Estimator

# %%
from vincent_util import (
    extract_features,
    reduce_dimensions,
    discretize_features,
    construct_bayesian_network_with_uncertainty,
    simplified_inference_test
)

print("Extracting features...")
#features, labels = extract_features(model, train_loader)
# features, labels = extract_features(model, dataloader)

features, labels = extract_features(model, small_loader)

print("Reducing Dimensionality...")
reduced_features, reducer, scaler = reduce_dimensions(
    features, 
    n_components=25
)

print("Discretizing features...")
discretized_features, bin_edges = discretize_features(reduced_features)
# Out:
# Extracting features...
# Extracting features:   0%|          | 0/125 [00:00<?, ?it/s]
# Reducing Dimensionality...
# PCA with 25 components explains 95.25% of variance
# Discretizing features...

# %%
pathologies = dataset.pathologies
print("Constructing Bayesian network with parameter uncertainty...")
bayes_net, param_samples, data, feature_cols, pathology_cols = construct_bayesian_network_with_uncertainty(
    reduced_features,
    # discretized_features, 
    labels,
    pathologies,
    bayesnet_struct="hill",
)
# Out:
# Constructing Bayesian network with parameter uncertainty...
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 pathologies = dataset.pathologies
#       2 print("Constructing Bayesian network with parameter uncertainty...")
# ----> 3 bayes_net, param_samples, data, feature_cols, pathology_cols = construct_bayesian_network_with_uncertainty(
#       4     reduced_features,
#       5     # discretized_features,
#       6     labels,
#       7     pathologies,
#       8     bayesnet_struct="hill",
#       9 )
#
# File ~/Desktop/uchic/courses/Winter2025/Bayesian/final_proj/vincent_util.py:580, in construct_bayesian_network_with_uncertainty(features, labels, pathologies, n_bins, equivalent_sample_size, n_parameter_samples, bayesnet_struct)
#     578 elif bayesnet_struct == "hill":
#     579     est_tree = HillClimbSearch(data)
# --> 580     best_model = est_tree.estimate()
#     581     model = BayesianNetwork(best_model)
#     583 elif bayesnet_struct == "exhaustive":
#
# File /opt/anaconda3/envs/bayes2/lib/python3.10/site-packages/pgmpy/estimators/HillClimbSearch.py:300, in HillClimbSearch.estimate(self, scoring_method, start_dag, fixed_edges, tabu_length, max_indegree, black_list, white_list, epsilon, max_iter, show_progress)
#     296 # Step 2: For each iteration, find the best scoring operation and
#     297 #         do that to the current model. If no legal operation is
#     298 #         possible, sets best_operation=None.
#     299 for _ in iteration:
# --> 300     best_operation, best_score_delta = max(
#     301         self._legal_operations(
#     302             current_model,
#     303             score_fn,
#     304             score.structure_prior_ratio,
#     305             tabu_list,
#     306             max_indegree,
#     307             black_list,
#     308             white_list,
#     309             fixed_edges,
#     310         ),
#     311         key=lambda t: t[1],
#     312         default=(None, None),
#     313     )
#     315     if best_operation is None or best_score_delta < epsilon:
#     316         break
#
# File /opt/anaconda3/envs/bayes2/lib/python3.10/site-packages/pgmpy/estimators/HillClimbSearch.py:114, in HillClimbSearch._legal_operations(self, model, score, structure_score, tabu_list, max_indegree, black_list, white_list, fixed_edges)
#     111 # Step 3: Get all legal operations for flipping edges
#     112 for X, Y in model.edges():
#     113     # Check if flipping creates any cycles
# --> 114     if not any(
#     115         map(lambda path: len(path) > 2, nx.all_simple_paths(model, X, Y))
#     116     ):
#     117         operation = ("flip", (X, Y))
#     118         if (
#     119             ((operation not in tabu_list) and ("flip", (Y, X)) not in tabu_list)
#     120             and ((X, Y) not in fixed_edges)
#     121             and ((Y, X) not in black_list)
#     122             and ((Y, X) in white_list)
#     123         ):
#
# File /opt/anaconda3/envs/bayes2/lib/python3.10/site-packages/networkx/algorithms/simple_paths.py:256, in all_simple_paths(G, source, target, cutoff)
#      94 @nx._dispatchable
#      95 def all_simple_paths(G, source, target, cutoff=None):
#      96     """Generate all simple paths in the graph G from source to target.
#      97
#      98     A simple path is a path with no repeated nodes.
#    (...)
#     254
#     255     """
# --> 256     for edge_path in all_simple_edge_paths(G, source, target, cutoff):
#     257         yield [source] + [edge[1] for edge in edge_path]
#
# File /opt/anaconda3/envs/bayes2/lib/python3.10/site-packages/networkx/algorithms/simple_paths.py:359, in all_simple_edge_paths(G, source, target, cutoff)
#     356 cutoff = cutoff if cutoff is not None else len(G) - 1
#     358 if cutoff >= 0 and targets:
# --> 359     yield from _all_simple_edge_paths(G, source, targets, cutoff)
#
# File /opt/anaconda3/envs/bayes2/lib/python3.10/site-packages/networkx/algorithms/simple_paths.py:384, in _all_simple_edge_paths(G, source, targets, cutoff)
#     380 stack = [iter([(None, source)])]
#     382 while stack:
#     383     # 1. Try to extend the current path.
# --> 384     next_edge = next((e for e in stack[-1] if e[1] not in current_path), None)
#     385     if next_edge is None:
#     386         # All edges of the last node in the current path have been explored.
#     387         stack.pop()
#
# KeyboardInterrupt:

# %%
results_df = simplified_inference_test(
    model=bayes_net,
    param_samples=param_samples,
    data=data,
    feature_cols=feature_cols,
    pathology_cols=pathology_cols,
    base_model_pred=preds[0],
    idx=0,
    n_samples=1000,
    n_test_samples=3
)
# Out:
# Processing sample 0 with features: {'f0': 0, 'f1': -28, 'f2': 9, 'f3': -4, 'f4': 7, 'f5': -11, 'f6': 13, 'f7': -3, 'f8': -10, 'f9': -8, 'f10': 0, 'f11': -6, 'f12': -4, 'f13': -2, 'f14': 0, 'f15': -5, 'f16': 3, 'f17': -3, 'f18': 2, 'f19': 0, 'f20': 1, 'f21': 0, 'f22': 3, 'f23': 4, 'f24': -3}
# Ground truth: {'Atelectasis': 0, 'Cardiomegaly': 0, 'Consolidation': 1, 'Edema': 0, 'Effusion': 0, 'Emphysema': 0, 'Fibrosis': 0, 'Hernia': 0, 'Infiltration': 1, 'Mass': 0, 'Nodule': 0, 'Pleural_Thickening': 1, 'Pneumonia': 0, 'Pneumothorax': 0}
# Traditional inference results:
#   Atelectasis: 0.3438 (Ground truth: 0)
#   Cardiomegaly: 0.4545 (Ground truth: 0)
#   Consolidation: 0.5000 (Ground truth: 1)
#   Edema: 0.4545 (Ground truth: 0)
#   Effusion: 0.4545 (Ground truth: 0)
#   Emphysema: 0.4545 (Ground truth: 0)
#   Fibrosis: 0.3125 (Ground truth: 0)
#   Hernia: 0.4545 (Ground truth: 0)
#   Infiltration: 0.3750 (Ground truth: 1)
#   Mass: 0.4545 (Ground truth: 0)
#   Nodule: 0.3125 (Ground truth: 0)
#   Pleural_Thickening: 0.2973 (Ground truth: 1)
#   Pneumonia: 0.3125 (Ground truth: 0)
#   Pneumothorax: 0.4545 (Ground truth: 0)
#
# Performing parameter sampling for uncertainty quantification...
# Using 1000 parameter samples from 1000 available
# Statistics for Atelectasis:
#   Ground truth: 0
#   MLE: 0.3438
#   MAP: 0.3535
#   Median with uncertainty: 0.3538
#   95% Credible Interval: [0.1728, 0.5610]
#   Standard deviation: 0.1007
#   Ground truth within 95% CI: False
#
# Statistics for Cardiomegaly:
#   Ground truth: 0
#   MLE: 0.4545
#   MAP: 0.4529
#   Median with uncertainty: 0.4506
#   95% Credible Interval: [0.2611, 0.6537]
#   Standard deviation: 0.0997
#   Ground truth within 95% CI: False
#
# Statistics for Consolidation:
#   Ground truth: 1
#   MLE: 0.5000
#   MAP: 0.4983
#   Median with uncertainty: 0.5012
#   95% Credible Interval: [0.3050, 0.6960]
#   Standard deviation: 0.1008
#   Ground truth within 95% CI: False
#
# Statistics for Edema:
#   Ground truth: 0
#   MLE: 0.4545
#   MAP: 0.4511
#   Median with uncertainty: 0.4536
#   95% Credible Interval: [0.2499, 0.6497]
#   Standard deviation: 0.1026
#   Ground truth within 95% CI: False
#
# Statistics for Effusion:
#   Ground truth: 0
#   MLE: 0.4545
#   MAP: 0.4603
#   Median with uncertainty: 0.4650
#   95% Credible Interval: [0.2690, 0.6540]
#   Standard deviation: 0.1000
#   Ground truth within 95% CI: False
#
# Statistics for Emphysema:
#   Ground truth: 0
#   MLE: 0.4545
#   MAP: 0.4501
#   Median with uncertainty: 0.4537
#   95% Credible Interval: [0.2502, 0.6399]
#   Standard deviation: 0.1009
#   Ground truth within 95% CI: False
#
# Statistics for Fibrosis:
#   Ground truth: 0
#   MLE: 0.3125
#   MAP: 0.3125
#   Median with uncertainty: 0.3095
#   95% Credible Interval: [0.1120, 0.5090]
#   Standard deviation: 0.1001
#   Ground truth within 95% CI: False
#
# Statistics for Hernia:
#   Ground truth: 0
#   MLE: 0.4545
#   MAP: 0.4564
#   Median with uncertainty: 0.4591
#   95% Credible Interval: [0.2546, 0.6423]
#   Standard deviation: 0.1001
#   Ground truth within 95% CI: False
#
# Statistics for Infiltration:
#   Ground truth: 1
#   MLE: 0.3750
#   MAP: 0.3752
#   Median with uncertainty: 0.3720
#   95% Credible Interval: [0.1779, 0.5797]
#   Standard deviation: 0.1020
#   Ground truth within 95% CI: False
#
# Statistics for Mass:
#   Ground truth: 0
#   MLE: 0.4545
#   MAP: 0.4519
#   Median with uncertainty: 0.4517
#   95% Credible Interval: [0.2620, 0.6448]
#   Standard deviation: 0.0985
#   Ground truth within 95% CI: False
#
# Statistics for Nodule:
#   Ground truth: 0
#   MLE: 0.3125
#   MAP: 0.3113
#   Median with uncertainty: 0.3125
#   95% Credible Interval: [0.1119, 0.5103]
#   Standard deviation: 0.0990
#   Ground truth within 95% CI: False
#
# Statistics for Pleural_Thickening:
#   Ground truth: 1
#   MLE: 0.2973
#   MAP: 0.3017
#   Median with uncertainty: 0.3022
#   95% Credible Interval: [0.1093, 0.4891]
#   Standard deviation: 0.1004
#   Ground truth within 95% CI: False
#
# Statistics for Pneumonia:
#   Ground truth: 0
#   MLE: 0.3125
#   MAP: 0.3148
#   Median with uncertainty: 0.3127
#   95% Credible Interval: [0.1228, 0.5178]
#   Standard deviation: 0.0996
#   Ground truth within 95% CI: False
#
# Statistics for Pneumothorax:
#   Ground truth: 0
#   MLE: 0.4545
#   MAP: 0.4524
#   Median with uncertainty: 0.4469
#   95% Credible Interval: [0.2630, 0.6417]
#   Standard deviation: 0.0982
#   Ground truth within 95% CI: False

# %%
results_df = simplified_inference_test(
    model=bayes_net,
    param_samples=param_samples,
    data=data,
    feature_cols=feature_cols,
    pathology_cols=pathology_cols,
    base_model_pred=preds[1],
    idx=1,
    n_samples=1000,
    n_test_samples=3
)
# Out:
# Processing sample 1 with features: {'f0': 12, 'f1': 0, 'f2': -11, 'f3': 7, 'f4': -9, 'f5': -11, 'f6': -3, 'f7': 0, 'f8': 5, 'f9': -4, 'f10': -5, 'f11': 3, 'f12': 0, 'f13': 0, 'f14': 0, 'f15': -1, 'f16': -1, 'f17': 0, 'f18': -2, 'f19': 1, 'f20': 0, 'f21': 0, 'f22': -1, 'f23': 1, 'f24': 1}
# Ground truth: {'Atelectasis': 0, 'Cardiomegaly': 0, 'Consolidation': 0, 'Edema': 0, 'Effusion': 0, 'Emphysema': 0, 'Fibrosis': 0, 'Hernia': 0, 'Infiltration': 0, 'Mass': 0, 'Nodule': 0, 'Pleural_Thickening': 0, 'Pneumonia': 0, 'Pneumothorax': 0}
# Traditional inference results:
#   Atelectasis: 0.3143 (Ground truth: 0)
#   Cardiomegaly: 0.1923 (Ground truth: 0)
#   Consolidation: 0.2308 (Ground truth: 0)
#   Edema: 0.1923 (Ground truth: 0)
#   Effusion: 0.1923 (Ground truth: 0)
#   Emphysema: 0.1923 (Ground truth: 0)
#   Fibrosis: 0.2857 (Ground truth: 0)
#   Hernia: 0.1923 (Ground truth: 0)
#   Infiltration: 0.2857 (Ground truth: 0)
#   Mass: 0.1923 (Ground truth: 0)
#   Nodule: 0.2857 (Ground truth: 0)
#   Pleural_Thickening: 0.4000 (Ground truth: 0)
#   Pneumonia: 0.2857 (Ground truth: 0)
#   Pneumothorax: 0.1923 (Ground truth: 0)
#
# Performing parameter sampling for uncertainty quantification...
# Using 1000 parameter samples from 1000 available
# Statistics for Atelectasis:
#   Ground truth: 0
#   MLE: 0.3143
#   MAP: 0.3161
#   Median with uncertainty: 0.3119
#   95% Credible Interval: [0.1232, 0.5142]
#   Standard deviation: 0.0998
#   Ground truth within 95% CI: False
#
# Statistics for Cardiomegaly:
#   Ground truth: 0
#   MLE: 0.1923
#   MAP: 0.1909
#   Median with uncertainty: 0.1906
#   95% Credible Interval: [0.0000, 0.3851]
#   Standard deviation: 0.0993
#   Ground truth within 95% CI: True
#
# Statistics for Consolidation:
#   Ground truth: 0
#   MLE: 0.2308
#   MAP: 0.2322
#   Median with uncertainty: 0.2335
#   95% Credible Interval: [0.0403, 0.4203]
#   Standard deviation: 0.0997
#   Ground truth within 95% CI: False
#
# Statistics for Edema:
#   Ground truth: 0
#   MLE: 0.1923
#   MAP: 0.1913
#   Median with uncertainty: 0.1910
#   95% Credible Interval: [0.0000, 0.3834]
#   Standard deviation: 0.0978
#   Ground truth within 95% CI: True
#
# Statistics for Effusion:
#   Ground truth: 0
#   MLE: 0.1923
#   MAP: 0.1924
#   Median with uncertainty: 0.1906
#   95% Credible Interval: [0.0000, 0.3854]
#   Standard deviation: 0.0984
#   Ground truth within 95% CI: True
#
# Statistics for Emphysema:
#   Ground truth: 0
#   MLE: 0.1923
#   MAP: 0.1944
#   Median with uncertainty: 0.1911
#   95% Credible Interval: [0.0034, 0.3957]
#   Standard deviation: 0.0965
#   Ground truth within 95% CI: False
#
# Statistics for Fibrosis:
#   Ground truth: 0
#   MLE: 0.2857
#   MAP: 0.2827
#   Median with uncertainty: 0.2827
#   95% Credible Interval: [0.0886, 0.4764]
#   Standard deviation: 0.0991
#   Ground truth within 95% CI: False
#
# Statistics for Hernia:
#   Ground truth: 0
#   MLE: 0.1923
#   MAP: 0.1939
#   Median with uncertainty: 0.1922
#   95% Credible Interval: [0.0000, 0.3778]
#   Standard deviation: 0.0960
#   Ground truth within 95% CI: True
#
# Statistics for Infiltration:
#   Ground truth: 0
#   MLE: 0.2857
#   MAP: 0.2841
#   Median with uncertainty: 0.2873
#   95% Credible Interval: [0.0900, 0.4654]
#   Standard deviation: 0.1001
#   Ground truth within 95% CI: False
#
# Statistics for Mass:
#   Ground truth: 0
#   MLE: 0.1923
#   MAP: 0.1940
#   Median with uncertainty: 0.1960
#   95% Credible Interval: [0.0000, 0.3887]
#   Standard deviation: 0.0976
#   Ground truth within 95% CI: True
#
# Statistics for Nodule:
#   Ground truth: 0
#   MLE: 0.2857
#   MAP: 0.2810
#   Median with uncertainty: 0.2800
#   95% Credible Interval: [0.0926, 0.4790]
#   Standard deviation: 0.0970
#   Ground truth within 95% CI: False
#
# Statistics for Pleural_Thickening:
#   Ground truth: 0
#   MLE: 0.4000
#   MAP: 0.3962
#   Median with uncertainty: 0.3957
#   95% Credible Interval: [0.2028, 0.5952]
#   Standard deviation: 0.1014
#   Ground truth within 95% CI: False
#
# Statistics for Pneumonia:
#   Ground truth: 0
#   MLE: 0.2857
#   MAP: 0.2932
#   Median with uncertainty: 0.2907
#   95% Credible Interval: [0.1155, 0.4728]
#   Standard deviation: 0.0967
#   Ground truth within 95% CI: False
#
# Statistics for Pneumothorax:
#   Ground truth: 0
#   MLE: 0.1923
#   MAP: 0.1939
#   Median with uncertainty: 0.1927
#   95% Credible Interval: [0.0000, 0.3865]
#   Standard deviation: 0.0967
#   Ground truth within 95% CI: True

# %%
results_df = simplified_inference_test(
    model=bayes_net,
    param_samples=param_samples,
    data=data,
    feature_cols=feature_cols,
    pathology_cols=pathology_cols,
    base_model_pred=preds[2],
    idx=2,
    n_samples=1000,
    n_test_samples=3
)
# Out:
# Processing sample 2 with features: {'f0': 3, 'f1': -10, 'f2': -18, 'f3': 14, 'f4': -11, 'f5': -15, 'f6': -6, 'f7': -8, 'f8': 8, 'f9': -9, 'f10': -3, 'f11': -3, 'f12': -3, 'f13': -3, 'f14': -2, 'f15': 4, 'f16': -5, 'f17': -1, 'f18': -3, 'f19': 3, 'f20': -2, 'f21': 0, 'f22': -1, 'f23': -4, 'f24': 0}
# Ground truth: {'Atelectasis': 0, 'Cardiomegaly': 0, 'Consolidation': 0, 'Edema': 0, 'Effusion': 0, 'Emphysema': 0, 'Fibrosis': 0, 'Hernia': 0, 'Infiltration': 0, 'Mass': 0, 'Nodule': 0, 'Pleural_Thickening': 0, 'Pneumonia': 0, 'Pneumothorax': 0}
# Traditional inference results:
#   Atelectasis: 0.3704 (Ground truth: 0)
#   Cardiomegaly: 0.3704 (Ground truth: 0)
#   Consolidation: 0.3704 (Ground truth: 0)
#   Edema: 0.3704 (Ground truth: 0)
#   Effusion: 0.3704 (Ground truth: 0)
#   Emphysema: 0.3704 (Ground truth: 0)
#   Fibrosis: 0.3704 (Ground truth: 0)
#   Hernia: 0.3704 (Ground truth: 0)
#   Infiltration: 0.3704 (Ground truth: 0)
#   Mass: 0.3704 (Ground truth: 0)
#   Nodule: 0.3704 (Ground truth: 0)
#   Pleural_Thickening: 0.4000 (Ground truth: 0)
#   Pneumonia: 0.3704 (Ground truth: 0)
#   Pneumothorax: 0.3704 (Ground truth: 0)
#
# Performing parameter sampling for uncertainty quantification...
# Using 1000 parameter samples from 1000 available
# Statistics for Atelectasis:
#   Ground truth: 0
#   MLE: 0.3704
#   MAP: 0.3649
#   Median with uncertainty: 0.3670
#   95% Credible Interval: [0.1671, 0.5618]
#   Standard deviation: 0.1015
#   Ground truth within 95% CI: False
#
# Statistics for Cardiomegaly:
#   Ground truth: 0
#   MLE: 0.3704
#   MAP: 0.3665
#   Median with uncertainty: 0.3685
#   95% Credible Interval: [0.1724, 0.5520]
#   Standard deviation: 0.0986
#   Ground truth within 95% CI: False
#
# Statistics for Consolidation:
#   Ground truth: 0
#   MLE: 0.3704
#   MAP: 0.3687
#   Median with uncertainty: 0.3662
#   95% Credible Interval: [0.1820, 0.5607]
#   Standard deviation: 0.0976
#   Ground truth within 95% CI: False
#
# Statistics for Edema:
#   Ground truth: 0
#   MLE: 0.3704
#   MAP: 0.3705
#   Median with uncertainty: 0.3673
#   95% Credible Interval: [0.1728, 0.5742]
#   Standard deviation: 0.1020
#   Ground truth within 95% CI: False
#
# Statistics for Effusion:
#   Ground truth: 0
#   MLE: 0.3704
#   MAP: 0.3698
#   Median with uncertainty: 0.3691
#   95% Credible Interval: [0.1752, 0.5556]
#   Standard deviation: 0.0977
#   Ground truth within 95% CI: False
#
# Statistics for Emphysema:
#   Ground truth: 0
#   MLE: 0.3704
#   MAP: 0.3644
#   Median with uncertainty: 0.3664
#   95% Credible Interval: [0.1686, 0.5581]
#   Standard deviation: 0.0974
#   Ground truth within 95% CI: False
#
# Statistics for Fibrosis:
#   Ground truth: 0
#   MLE: 0.3704
#   MAP: 0.3691
#   Median with uncertainty: 0.3677
#   95% Credible Interval: [0.1954, 0.5543]
#   Standard deviation: 0.0950
#   Ground truth within 95% CI: False
#
# Statistics for Hernia:
#   Ground truth: 0
#   MLE: 0.3704
#   MAP: 0.3733
#   Median with uncertainty: 0.3713
#   95% Credible Interval: [0.1705, 0.5758]
#   Standard deviation: 0.1013
#   Ground truth within 95% CI: False
#
# Statistics for Infiltration:
#   Ground truth: 0
#   MLE: 0.3704
#   MAP: 0.3714
#   Median with uncertainty: 0.3691
#   95% Credible Interval: [0.1773, 0.5645]
#   Standard deviation: 0.0981
#   Ground truth within 95% CI: False
#
# Statistics for Mass:
#   Ground truth: 0
#   MLE: 0.3704
#   MAP: 0.3720
#   Median with uncertainty: 0.3723
#   95% Credible Interval: [0.1856, 0.5673]
#   Standard deviation: 0.0973
#   Ground truth within 95% CI: False
#
# Statistics for Nodule:
#   Ground truth: 0
#   MLE: 0.3704
#   MAP: 0.3748
#   Median with uncertainty: 0.3728
#   95% Credible Interval: [0.1724, 0.5756]
#   Standard deviation: 0.1014
#   Ground truth within 95% CI: False
#
# Statistics for Pleural_Thickening:
#   Ground truth: 0
#   MLE: 0.4000
#   MAP: 0.4042
#   Median with uncertainty: 0.4053
#   95% Credible Interval: [0.2075, 0.6049]
#   Standard deviation: 0.1008
#   Ground truth within 95% CI: False
#
# Statistics for Pneumonia:
#   Ground truth: 0
#   MLE: 0.3704
#   MAP: 0.3736
#   Median with uncertainty: 0.3740
#   95% Credible Interval: [0.1802, 0.5703]
#   Standard deviation: 0.1004
#   Ground truth within 95% CI: False
#
# Statistics for Pneumothorax:
#   Ground truth: 0
#   MLE: 0.3704
#   MAP: 0.3670
#   Median with uncertainty: 0.3680
#   95% Credible Interval: [0.1701, 0.5710]
#   Standard deviation: 0.1033
#   Ground truth within 95% CI: False

# %%
results_df = simplified_inference_test(
    model=bayes_net,
    param_samples=param_samples,
    data=data,
    feature_cols=feature_cols,
    pathology_cols=pathology_cols,
    base_model_pred=preds[3],
    idx=3,
    n_samples=1000,
    n_test_samples=3
)
# Out:
# Processing sample 3 with features: {'f0': -15, 'f1': -13, 'f2': 5, 'f3': 12, 'f4': 3, 'f5': 9, 'f6': 0, 'f7': 9, 'f8': 3, 'f9': 0, 'f10': -3, 'f11': 0, 'f12': 0, 'f13': 3, 'f14': 0, 'f15': 5, 'f16': -1, 'f17': 0, 'f18': -3, 'f19': 1, 'f20': 2, 'f21': -1, 'f22': 0, 'f23': -2, 'f24': 0}
# Ground truth: {'Atelectasis': 1, 'Cardiomegaly': 0, 'Consolidation': 0, 'Edema': 0, 'Effusion': 0, 'Emphysema': 0, 'Fibrosis': 0, 'Hernia': 0, 'Infiltration': 0, 'Mass': 0, 'Nodule': 0, 'Pleural_Thickening': 0, 'Pneumonia': 0, 'Pneumothorax': 0}
# Traditional inference results:
#   Atelectasis: 0.3929 (Ground truth: 1)
#   Cardiomegaly: 0.3793 (Ground truth: 0)
#   Consolidation: 0.3448 (Ground truth: 0)
#   Edema: 0.3448 (Ground truth: 0)
#   Effusion: 0.3448 (Ground truth: 0)
#   Emphysema: 0.3448 (Ground truth: 0)
#   Fibrosis: 0.4286 (Ground truth: 0)
#   Hernia: 0.3793 (Ground truth: 0)
#   Infiltration: 0.3571 (Ground truth: 0)
#   Mass: 0.3448 (Ground truth: 0)
#   Nodule: 0.3571 (Ground truth: 0)
#   Pleural_Thickening: 0.2407 (Ground truth: 0)
#   Pneumonia: 0.3571 (Ground truth: 0)
#   Pneumothorax: 0.3448 (Ground truth: 0)
#
# Performing parameter sampling for uncertainty quantification...
# Using 1000 parameter samples from 1000 available
# Statistics for Atelectasis:
#   Ground truth: 1
#   MLE: 0.3929
#   MAP: 0.3954
#   Median with uncertainty: 0.3996
#   95% Credible Interval: [0.2004, 0.5859]
#   Standard deviation: 0.0993
#   Ground truth within 95% CI: False
#
# Statistics for Cardiomegaly:
#   Ground truth: 0
#   MLE: 0.3793
#   MAP: 0.3753
#   Median with uncertainty: 0.3767
#   95% Credible Interval: [0.1824, 0.5638]
#   Standard deviation: 0.0979
#   Ground truth within 95% CI: False
#
# Statistics for Consolidation:
#   Ground truth: 0
#   MLE: 0.3448
#   MAP: 0.3493
#   Median with uncertainty: 0.3537
#   95% Credible Interval: [0.1461, 0.5407]
#   Standard deviation: 0.0994
#   Ground truth within 95% CI: False
#
# Statistics for Edema:
#   Ground truth: 0
#   MLE: 0.3448
#   MAP: 0.3430
#   Median with uncertainty: 0.3428
#   95% Credible Interval: [0.1353, 0.5483]
#   Standard deviation: 0.1033
#   Ground truth within 95% CI: False
#
# Statistics for Effusion:
#   Ground truth: 0
#   MLE: 0.3448
#   MAP: 0.3464
#   Median with uncertainty: 0.3436
#   95% Credible Interval: [0.1510, 0.5454]
#   Standard deviation: 0.1030
#   Ground truth within 95% CI: False
#
# Statistics for Emphysema:
#   Ground truth: 0
#   MLE: 0.3448
#   MAP: 0.3484
#   Median with uncertainty: 0.3457
#   95% Credible Interval: [0.1556, 0.5563]
#   Standard deviation: 0.1026
#   Ground truth within 95% CI: False
#
# Statistics for Fibrosis:
#   Ground truth: 0
#   MLE: 0.4286
#   MAP: 0.4279
#   Median with uncertainty: 0.4280
#   95% Credible Interval: [0.2276, 0.6352]
#   Standard deviation: 0.1021
#   Ground truth within 95% CI: False
#
# Statistics for Hernia:
#   Ground truth: 0
#   MLE: 0.3793
#   MAP: 0.3810
#   Median with uncertainty: 0.3839
#   95% Credible Interval: [0.1761, 0.5711]
#   Standard deviation: 0.1027
#   Ground truth within 95% CI: False
#
# Statistics for Infiltration:
#   Ground truth: 0
#   MLE: 0.3571
#   MAP: 0.3579
#   Median with uncertainty: 0.3548
#   95% Credible Interval: [0.1635, 0.5589]
#   Standard deviation: 0.1001
#   Ground truth within 95% CI: False
#
# Statistics for Mass:
#   Ground truth: 0
#   MLE: 0.3448
#   MAP: 0.3447
#   Median with uncertainty: 0.3450
#   95% Credible Interval: [0.1472, 0.5255]
#   Standard deviation: 0.0979
#   Ground truth within 95% CI: False
#
# Statistics for Nodule:
#   Ground truth: 0
#   MLE: 0.3571
#   MAP: 0.3541
#   Median with uncertainty: 0.3537
#   95% Credible Interval: [0.1680, 0.5502]
#   Standard deviation: 0.0978
#   Ground truth within 95% CI: False
#
# Statistics for Pleural_Thickening:
#   Ground truth: 0
#   MLE: 0.2407
#   MAP: 0.2458
#   Median with uncertainty: 0.2427
#   95% Credible Interval: [0.0667, 0.4450]
#   Standard deviation: 0.0974
#   Ground truth within 95% CI: False
#
# Statistics for Pneumonia:
#   Ground truth: 0
#   MLE: 0.3571
#   MAP: 0.3570
#   Median with uncertainty: 0.3601
#   95% Credible Interval: [0.1677, 0.5474]
#   Standard deviation: 0.0997
#   Ground truth within 95% CI: False
#
# Statistics for Pneumothorax:
#   Ground truth: 0
#   MLE: 0.3448
#   MAP: 0.3439
#   Median with uncertainty: 0.3412
#   95% Credible Interval: [0.1490, 0.5369]
#   Standard deviation: 0.1006
#   Ground truth within 95% CI: False

# %% [markdown]
#  ## Visualize the Bayes Net

# %%
# Import the required libraries
import networkx as nx
import matplotlib.pyplot as plt

# Create a directed graph from your Bayesian network
G = nx.DiGraph()

# Add nodes
G.add_nodes_from(bayes_net.nodes())

# Add edges
G.add_edges_from(bayes_net.edges())

# Draw the graph
plt.figure(figsize=(15, 10))
pos = nx.spring_layout(G, seed=42)  # For reproducibility
nx.draw(G, pos, with_labels=True, node_size=2000, node_color="skyblue", 
        font_size=10, font_weight="bold", arrowsize=20, 
        edge_color="gray", width=2)

plt.title("Bayesian Network Structure", fontsize=15)
plt.tight_layout()
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# Assuming bayes_net is your Bayesian network
G = nx.DiGraph()
G.add_nodes_from(bayes_net.nodes())
G.add_edges_from(bayes_net.edges())

# Identify disease/condition nodes vs feature nodes
disease_nodes = [n for n in G.nodes() if not n.startswith('f')]
feature_nodes = [n for n in G.nodes() if n.startswith('f')]

# Option 1: Show just the disease/condition nodes and their relationships
disease_graph = G.subgraph(disease_nodes)

plt.figure(figsize=(10, 8))
pos = nx.spring_layout(disease_graph, seed=42)
nx.draw_networkx(disease_graph, pos, 
                node_color='lightgreen',
                node_size=2000,
                font_size=12,
                font_weight='bold')
plt.title("Relationships Between Disease/Condition Nodes")
plt.tight_layout()
plt.show()

# %%
disease_of_interest = "Pneumonia"  # Change to any disease node
neighbors = list(G.predecessors(disease_of_interest)) + list(G.successors(disease_of_interest))
relevant_nodes = [disease_of_interest] + neighbors

subgraph = G.subgraph(relevant_nodes)
plt.figure(figsize=(12, 10))
pos = nx.spring_layout(subgraph, seed=42)

nx.draw_networkx_nodes(subgraph, pos,
                      nodelist=[disease_of_interest],
                      node_color='red',
                      node_size=3000)
nx.draw_networkx_nodes(subgraph, pos,
                      nodelist=[n for n in subgraph.nodes() if n != disease_of_interest],
                      node_color='skyblue',
                      node_size=1500)
nx.draw_networkx_edges(subgraph, pos, arrows=True)
nx.draw_networkx_labels(subgraph, pos, font_size=10, font_weight='bold')

plt.title(f"Network for {disease_of_interest}")
plt.tight_layout()
plt.show()
